# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\patri\Downloads\Ex_Files_Python_Statistics_EssT\Ex_Files_Python_Statistics_EssT\Exercise Files\chapter2\02_02\Book1.csv')

# %%
df
# Out:
#     Planet       Mass Diameter  DayLength  SunDistance OrbitPeriod  \
# 0  MERCURY     0.3300     4879     4222.6         57.9          88
# 1    VENUS     4.8700   12,104     2802.0        108.2       224.7
# 2    EARTH     5.9700   12,756       24.0        149.6       365.2
# 3     MOON     0.0730     3475      708.7          NaN        27.3
# 4     MARS     0.6420     6792       24.7        227.9         687
# 5  JUPITER  1898.0000  142,984        9.9        778.6        4331
# 6   SATURN   568.0000  120,536       10.7       1433.5      10,747
# 7   URANUS    86.8000   51,118       17.2       2872.5      30,589
# 8  NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# 9    PLUTO     0.0146     2370      153.3       5906.4      90,560
#
#    OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167          0.00000      0    No           Yes
# ...

# %%
df = pd.read_csv(r'C:\Users\patri\Downloads\Ex_Files_Python_Statistics_EssT\Ex_Files_Python_Statistics_EssT\Exercise Files\chapter2\02_02\Book1.csv',usecols=[0,1,2,3])

# %%
df
# Out:
#     Planet       Mass Diameter  DayLength
# 0  MERCURY     0.3300     4879     4222.6
# 1    VENUS     4.8700   12,104     2802.0
# 2    EARTH     5.9700   12,756       24.0
# 3     MOON     0.0730     3475      708.7
# 4     MARS     0.6420     6792       24.7
# 5  JUPITER  1898.0000  142,984        9.9
# 6   SATURN   568.0000  120,536       10.7
# 7   URANUS    86.8000   51,118       17.2
# 8  NEPTUNE   102.0000   49,528       16.1
# 9    PLUTO     0.0146     2370      153.3

# %%
df['Mass']
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.loc[0]
# Out:
# Planet       MERCURY
# Mass            0.33
# Diameter        4879
# DayLength     4222.6
# Name: 0, dtype: object

# %%
df.set_index('Planet',inplace=True)

# %%
df
# Out:
#               Mass Diameter  DayLength
# Planet
# MERCURY     0.3300     4879     4222.6
# VENUS       4.8700   12,104     2802.0
# EARTH       5.9700   12,756       24.0
# MOON        0.0730     3475      708.7
# MARS        0.6420     6792       24.7
# JUPITER  1898.0000  142,984        9.9
# SATURN    568.0000  120,536       10.7
# URANUS     86.8000   51,118       17.2
# NEPTUNE   102.0000   49,528       16.1
# PLUTO       0.0146     2370      153.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, MERCURY to PLUTO
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Mass       10 non-null     float64
#  1   Diameter   10 non-null     object
#  2   DayLength  10 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 320.0+ bytes

# %%
len(df)
# Out:
# 10

# %%
df.loc['MERCURY':'EARTH']
# Out:
#          Mass Diameter  DayLength
# Planet
# MERCURY  0.33     4879     4222.6
# VENUS    4.87   12,104     2802.0
# EARTH    5.97   12,756       24.0

# %%
df.columns
# Out:
# Index(['Mass', 'Diameter', 'DayLength'], dtype='object')

# %%
df = pd.read_csv(r'C:\Users\patri\Downloads\Ex_Files_Python_Statistics_EssT\Ex_Files_Python_Statistics_EssT\Exercise Files\chapter2\02_02\Book1.csv')

# %%
df.set_index('Planet', inplace=True)

# %%
df
# Out:
#               Mass Diameter  DayLength  SunDistance OrbitPeriod  \
# Planet
# MERCURY     0.3300     4879     4222.6         57.9          88
# VENUS       4.8700   12,104     2802.0        108.2       224.7
# EARTH       5.9700   12,756       24.0        149.6       365.2
# MOON        0.0730     3475      708.7          NaN        27.3
# MARS        0.6420     6792       24.7        227.9         687
# JUPITER  1898.0000  142,984        9.9        778.6        4331
# SATURN    568.0000  120,536       10.7       1433.5      10,747
# URANUS     86.8000   51,118       17.2       2872.5      30,589
# NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# PLUTO       0.0146     2370      153.3       5906.4      90,560
#
#          OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings  \
# Planet
# MERCURY           47.4              167          0.00000      0    No
# VENUS             35.0              464         92.00000      0    No
# ...

# %%
df.FirstVisited['MERCURY']
# Out:
# '1974-03-29'

# %%
df.loc['MERCURY'].FirstVisited
# Out:
# '1974-03-29'

# %%
df.loc['MERCURY', 'FirstVisited']
# Out:
# '1974-03-29'

# %%
type(df.loc['MERCURY', 'FirstVisited'])
# Out:
# str

# %%
pd.to_datetime(df.FirstVisited)
# Out:
# Planet
# MERCURY   1974-03-29
# VENUS     1962-08-27
# EARTH            NaT
# MOON      1959-09-12
# MARS      1965-07-15
# JUPITER   1973-12-04
# SATURN    1979-09-01
# URANUS    1986-01-24
# NEPTUNE   1989-08-25
# PLUTO     2015-07-14
# Name: FirstVisited, dtype: datetime64[ns]

# %%
df.FirstVisited = pd.to_datetime(df.FirstVisited)

# %%
df.FirstVisited.dt.year
# Out:
# Planet
# MERCURY    1974.0
# VENUS      1962.0
# EARTH         NaN
# MOON       1959.0
# MARS       1965.0
# JUPITER    1973.0
# SATURN     1979.0
# URANUS     1986.0
# NEPTUNE    1989.0
# PLUTO      2015.0
# Name: FirstVisited, dtype: float64

# %%
2021- df.FirstVisited.dt.year
# Out:
# Planet
# MERCURY    47.0
# VENUS      59.0
# EARTH       NaN
# MOON       62.0
# MARS       56.0
# JUPITER    48.0
# SATURN     42.0
# URANUS     35.0
# NEPTUNE    32.0
# PLUTO       6.0
# Name: FirstVisited, dtype: float64

# %%
billboard = pd.read_csv(r'C:\Users\patri\Downloads\Ex_Files_Python_Statistics_EssT\Ex_Files_Python_Statistics_EssT\Exercise Files\chapter2\02_04\billboard.csv')

# %%
billboard.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
billboard.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
plt.plot(billboard.loc[0,'x1st.week':'x76th.week'])

# %%
plt.plot(range(1,77),billboard.loc[0,'x1st.week':'x76th.week'])

# %%
for index, row in billboard.iterrows():
    plt.plot(range(1,77),row['x1st.week':'x76th.week'],alpha=0.1)

# %%
billboard.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
bshort = billboard[['artist.inverted','track','time','date.entered','x1st.week','x2nd.week','x3rd.week']]

# %%
bshort.head()
# Out:
#        artist.inverted                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  x1st.week  x2nd.week  x3rd.week
# 0   2000-09-23         78       63.0       49.0
# 1   2000-02-12         15        8.0        6.0
# 2   1999-10-23         71       48.0       43.0
# 3   2000-08-12         41       23.0       18.0
# 4   2000-08-05         57       47.0       45.0

# %%
bshort.columns = ['artist', 'track','time', 'date.entered','wk1','wk2','wk3']
bshort.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  wk1   wk2   wk3
# 0   2000-09-23   78  63.0  49.0
# 1   2000-02-12   15   8.0   6.0
# 2   1999-10-23   71  48.0  43.0
# 3   2000-08-12   41  23.0  18.0
# 4   2000-08-05   57  47.0  45.0

# %%
bmelt = bshort.melt(['artist','track','time','date.entered'],['wk1','wk2','wk3'],'week','rank')
bmelt.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered week  rank
# 0   2000-09-23  wk1  78.0
# 1   2000-02-12  wk1  15.0
# 2   1999-10-23  wk1  71.0
# 3   2000-08-12  wk1  41.0
# 4   2000-08-05  wk1  57.0

# %%
bmelt.query('track == "Liar"')
# Out:
#       artist track  time date.entered week  rank
# 66   Profyle  Liar  3:57   2000-09-16  wk1  52.0
# 383  Profyle  Liar  3:57   2000-09-16  wk2  32.0
# 700  Profyle  Liar  3:57   2000-09-16  wk3  25.0

# %%
bmelt['date.entered'] = pd.to_datetime(bmelt['date.entered'])

# %%
bmelt['date.entered'][0] + pd.Timedelta('7 days')
# Out:
# Timestamp('2000-09-30 00:00:00')

# %%
bmelt.drop(['date.entered'],axis=1,inplace=True)

# %%
bmelt.head()
# Out:
#                 artist                                  track  time week  rank
# 0      Destiny's Child               Independent Women Part I  3:38  wk1  78.0
# 1              Santana                           Maria, Maria  4:18  wk1  15.0
# 2        Savage Garden                     I Knew I Loved You  4:07  wk1  71.0
# 3              Madonna                                  Music  3:45  wk1  41.0
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38  wk1  57.0
